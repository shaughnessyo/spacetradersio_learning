# %%
from data_decode import data_decode
from space_traders_api_client.api.systems import get_jump_gate
from client import client
import pickle

with open("system_list.pickle", "rb") as f:
    full_system_list = pickle.load(f)

print(full_system_list[0]['symbol'])


for system in full_system_list:
    # print(system)
    if system['symbol'] == "X1-CJ75":
        for waypoint in system['waypoints']:
            print(waypoint)
            #todo this is enough to store as a base table in postgresql
            # print(system['symbol'], waypoint['symbol'], waypoint['type'])
            system_symbol = system['symbol']
            if waypoint['type'] == "JUMP_GATE":
                jump_gate_response = get_jump_gate.sync_detailed(system['symbol'], waypoint['symbol'], client=client)
                jump_gate_response = data_decode(jump_gate_response.content)
                jump_gate_list = []
                for system in jump_gate_response['connectedSystems']:
                    jump_gate_list.append(system['symbol'])
                # print(system['symbol'],jump_gate_response['connectedSystems'])
            print(system_symbol, jump_gate_list)
        # print(system)
# print(full_system_list["X1-CJ75"])
# Out:
# X1-JF24
# {'symbol': 'X1-CJ75-63510E', 'type': 'PLANET', 'x': -14, 'y': -41}
# X1-CJ75 X1-CJ75-63510E PLANET
# X1-CJ75 ['X1-UU16', 'X1-MR92', 'X1-KG98', 'X1-NX11', 'X1-FT22', 'X1-VB40', 'X1-QH20', 'X1-RX26', 'X1-BG97', 'X1-RR26', 'X1-Z32']
# {'symbol': 'X1-CJ75-28251A', 'type': 'MOON', 'x': -14, 'y': -41}
# X1-CJ75 X1-CJ75-28251A MOON
# X1-CJ75 ['X1-UU16', 'X1-MR92', 'X1-KG98', 'X1-NX11', 'X1-FT22', 'X1-VB40', 'X1-QH20', 'X1-RX26', 'X1-BG97', 'X1-RR26', 'X1-Z32']
# {'symbol': 'X1-CJ75-59602F', 'type': 'MOON', 'x': -14, 'y': -41}
# X1-CJ75 X1-CJ75-59602F MOON
# X1-CJ75 ['X1-UU16', 'X1-MR92', 'X1-KG98', 'X1-NX11', 'X1-FT22', 'X1-VB40', 'X1-QH20', 'X1-RX26', 'X1-BG97', 'X1-RR26', 'X1-Z32']
# {'symbol': 'X1-CJ75-72833Z', 'type': 'PLANET', 'x': -8, 'y': -57}
# X1-CJ75 X1-CJ75-72833Z PLANET
# X1-CJ75 ['X1-UU16', 'X1-MR92', 'X1-KG98', 'X1-NX11', 'X1-FT22', 'X1-VB40', 'X1-QH20', 'X1-RX26', 'X1-BG97', 'X1-RR26', 'X1-Z32']
# {'symbol': 'X1-CJ75-27244D', 'type': 'MOON', 'x': -8, 'y': -57}
# ...

# %%
#TODO i forgot this was building towards using a table lookup in postgresql to handle jump gates


from data_decode import data_decode
from space_traders_api_client.api.systems import get_jump_gate
from client import client
import pickle
from time import sleep
from data_to_sql import system_waypoints_to_sql

with open("system_list.pickle", "rb") as f:
    full_system_list = pickle.load(f)

# print(full_system_list[0]['symbol'])


for system in full_system_list[0:200]:
    # print(system)
    # if system['symbol'] == "X1-CJ75":
    for waypoint in system['waypoints']:
        # print(waypoint)
        #todo this is enough to store as a base table in postgresql
        # print(system['symbol'], waypoint['symbol'], waypoint['type'])
        system_symbol = system['symbol']
        jumpgate_list = []
        if waypoint['type'] == "JUMP_GATE":
            sleep(.5)
            jump_gate_response = get_jump_gate.sync_detailed(system['symbol'], waypoint['symbol'], client=client)
            jump_gate_response = data_decode(jump_gate_response.content)

            for jg in jump_gate_response['connectedSystems']:
                jumpgate_list.append(jg['symbol'])
            # print(system['symbol'],jump_gate_response['connectedSystems'])
        system_waypoints_to_sql(system_symbol=system_symbol, waypoint_symbol=waypoint['symbol'],
                                waypoint_type=waypoint['type'],jumpgate_list=jumpgate_list)
        print(system_symbol, waypoint['symbol'], waypoint['type'], jumpgate_list)
# Out:
# X1-JF24
# X1-JF24 X1-JF24-77691C PLANET []
# X1-JF24 X1-JF24-06790Z PLANET []
# X1-JF24 X1-JF24-97552X MOON []
# X1-JF24 X1-JF24-78153C MOON []
# X1-JF24 X1-JF24-01924F MOON []
# X1-JF24 X1-JF24-23225F ASTEROID_FIELD []
# X1-JF24 X1-JF24-45556D GAS_GIANT []
# X1-JF24 X1-JF24-73757X ORBITAL_STATION []
# X1-JF24 X1-JF24-34538X PLANET []
# X1-JF24 X1-JF24-00189Z JUMP_GATE ['X1-KB63', 'X1-YX61', 'X1-ZF49', 'X1-M73', 'X1-UH84', 'X1-VB95', 'X1-UD25', 'X1-QM91', 'X1-VM9', 'X1-UM75']
# X1-KB63 X1-KB63-36710X PLANET []
# X1-KB63 X1-KB63-04111X MOON []
# X1-KB63 X1-KB63-06312C GAS_GIANT []
# X1-KB63 X1-KB63-52913Z ORBITAL_STATION []
# X1-KB63 X1-KB63-26314F ASTEROID_FIELD []
# X1-KB63 X1-KB63-53515F JUMP_GATE ['X1-JF24', 'X1-YX61', 'X1-ZF49', 'X1-M73', 'X1-UH84', 'X1-VB95', 'X1-UD25', 'X1-QM91', 'X1-VM9']
# X1-M73 X1-M73-50630B PLANET []
# X1-M73 X1-M73-18621E MOON []
# X1-M73 X1-M73-96262D PLANET []
# X1-M73 X1-M73-35743E PLANET []
# X1-M73 X1-M73-33594F MOON []
# ...

# %%
#this needs to lookup the system_waypoints table eventually in the style of a dict like
# sql_lookup[system]: jumpgate list

import pandas as pd
import sqlalchemy as sa

engine = sa.create_engine('postgresql://postgres:lasers@localhost:5432/spacetraders')

#check to see if i can get more specific sql query
df_test = pd.read_sql("system_waypoints", engine)

df_systems_in_jumpgate_range = pd.read_sql("select * from system_waypoints where waypoint_type = 'JUMP_GATE'", engine)


def system_sql_lookup(ship_system: str):
    df_sys_jg_lookup = pd.read_sql("SELECT * FROM system_waypoints WHERE 'system_symbol' = 'ship_system';")
    print(df_sys_jg_lookup)


system_sql_lookup("X1-M73")



print(df_systems_in_jumpgate_range)

jumpgate_list = df_systems_in_jumpgate_range['jumpgate_list'].values.tolist()
# system = df_systems_in_jumpgate_range['system'].to_numpy()[0]
print("values.tolist()", jumpgate_list)

#todo reminder: you're building towards a dict to do easy jumpgate lookups OR use a method to wrap an sql query

# jumpgate_list = jumpgate_list[0].replace('{', '').replace('}', '')
jumpgate_list = jumpgate_list[0].replace('{', '').replace('}', '')
jumpgate_list = jumpgate_list.split(',')

print(jumpgate_list)


# jumpgate_list =
# deposits_from_sql = best_survey['deposits'].values.tolist()
# # print(deposits_from_sql[0].replace('{', '[').replace('}', ']'))
#
# # deposits_from_sql = deposits_from_sql[0].replace('{','[').replace('}',']')
# deposits_from_sql = deposits_from_sql[0].replace('{', '').replace('}', '')
# deposits_from_sql = deposits_from_sql.split(',')
#
# # print(deposits_from_sql)
# deposit_list = []
#
# for item in deposits_from_sql:
#     deposit_obj = SurveyDeposit(item)
#     deposit_list.append(deposit_obj)
# Out:
#        id system_symbol waypoint_symbol waypoint_type  \
# 0      10       X1-JF24  X1-JF24-00189Z     JUMP_GATE
# 1      16       X1-KB63  X1-KB63-53515F     JUMP_GATE
# 2      22        X1-M73   X1-M73-87165Z     JUMP_GATE
# 3      29       X1-UH84  X1-UH84-22785A     JUMP_GATE
# 4      38       X1-YX61  X1-YX61-54698Z     JUMP_GATE
# ..    ...           ...             ...           ...
# 164  3934       X1-PK97  X1-PK97-56212D     JUMP_GATE
# 165  3940       X1-DD58  X1-DD58-99855A     JUMP_GATE
# 166  3949       X1-JH58  X1-JH58-03398A     JUMP_GATE
# 167  3989       X1-PB88  X1-PB88-07089D     JUMP_GATE
# 168  3996       X1-CM87  X1-CM87-59776F     JUMP_GATE
#
#                                          jumpgate_list
# 0    {X1-KB63,X1-YX61,X1-ZF49,X1-M73,X1-UH84,X1-VB9...
# 1    {X1-JF24,X1-YX61,X1-ZF49,X1-M73,X1-UH84,X1-VB9...
# 2    {X1-UH84,X1-VB95,X1-UD25,X1-JF24,X1-ZF49,X1-YX...
# 3    {X1-M73,X1-UD25,X1-VB95,X1-JF24,X1-ZF49,X1-YX6...
# ...

# %%
#this needs to lookup the system_waypoints table eventually in the style of a dict like
# sql_lookup[system]: jumpgate list

import pandas as pd
import sqlalchemy as sa

engine = sa.create_engine('postgresql://postgres:lasers@localhost:5432/spacetraders')

#check to see if i can get more specific sql query
df_test = pd.read_sql("system_waypoints", engine)

df_systems_in_jumpgate_range = pd.read_sql("select * from system_waypoints where waypoint_type = 'JUMP_GATE'", engine)


df_test = pd.read_sql("SELECT * FROM system_waypoints where system_symbol = 'X1-JF24' and waypoint_type = 'JUMP_GATE'", engine)
print(df_test)

# yeah this sort of query isn't right
def system_sql_lookup(ship_system: str):
    sql_query = pd.read_sql_query("''SELECT * FROM COURSES where 'system_symbol' = 'X1-M73''", engine)
    df_sys_jg_lookup = pd.read_sql(f"SELECT * FROM system_waypoints WHERE 'system_symbol' = '{ship_system}'",engine)
    print(df_sys_jg_lookup)


system_sql_lookup("X1-M73")
# Out:
# Empty DataFrame
# Columns: [id, system_symbol, waypoint_symbol, waypoint_type, jumpgate_list]
# Index: []

# %%
from get_ships import ship_list

#######TODO this is the query that works, the f string took some tinkering

#todo this should be a ship method


def system_sql_lookup(ship_system: str):
    df_system_jumpgate_list = pd.read_sql(f"SELECT * FROM system_waypoints where system_symbol = '{system_symbol}' and waypoint_type = 'JUMP_GATE'", engine)
    print(df_system_jumpgate_list)

system_symbol = 'X1-JF24'
system_sql_lookup(system_symbol)
# Out:
#    id system_symbol waypoint_symbol waypoint_type  \
# 0  10       X1-JF24  X1-JF24-00189Z     JUMP_GATE
#
#                                        jumpgate_list
# 0  {X1-KB63,X1-YX61,X1-ZF49,X1-M73,X1-UH84,X1-VB9...

# %%
import psycopg2.extras

conn = psycopg2.connect(
    database="spacetraders", user='postgres', password='lasers',
    host='127.0.0.1', port='5432'
)

conn.autocommit = True
cursor = conn.cursor()

sql1 = '''select * from system_waypoints;'''
cursor.execute(sql1)
results = cursor.fetchall()

print(results[0])

jumpgate_lookup_dict = {}
for row in results:
    if row[3] == "JUMP_GATE":
        print(f"system: {row[1]},"
              f" system_waypoint: {row[2]},"
              f" waypoint_type {row[3]},"
              f" systems_in_range {row[4]}")
        sys_symbol = row[1]
        jumpgate_list = row[4]
        jg_test = jumpgate_list.split(',')
        jg_cleaned = []
        for jg in jg_test:
            # print(jg.replace('{','').replace('}',''))
            jg_cleaned.append(jg.replace('{','').replace('}',''))
        jumpgate_lookup_dict[sys_symbol] = jg_cleaned

print(jumpgate_lookup_dict.items())

print('hey', jumpgate_lookup_dict.items()[0])
conn.commit()
conn.close()

#index, system, system_waypoint, waypoint_type, systems in jump range if type== jumpgate

# 10	"X1-JF24"	"X1-JF24-00189Z"	"JUMP_GATE"	"{X1-KB63,X1-YX61,X1-ZF49,X1-M73,X1-UH84,X1-VB95,X1-UD25,X1-QM91,X1-VM9,X1-UM75}"
# Out:
# (1, 'X1-JF24', 'X1-JF24-77691C', 'PLANET', '{}')
# system: X1-JF24, system_waypoint: X1-JF24-00189Z, waypoint_type JUMP_GATE, systems_in_range {X1-KB63,X1-YX61,X1-ZF49,X1-M73,X1-UH84,X1-VB95,X1-UD25,X1-QM91,X1-VM9,X1-UM75}
# system: X1-KB63, system_waypoint: X1-KB63-53515F, waypoint_type JUMP_GATE, systems_in_range {X1-JF24,X1-YX61,X1-ZF49,X1-M73,X1-UH84,X1-VB95,X1-UD25,X1-QM91,X1-VM9}
# system: X1-M73, system_waypoint: X1-M73-87165Z, waypoint_type JUMP_GATE, systems_in_range {X1-UH84,X1-VB95,X1-UD25,X1-JF24,X1-ZF49,X1-YX61,X1-KB63,X1-VM9,X1-UM75,X1-QM91,X1-PU62}
# system: X1-UH84, system_waypoint: X1-UH84-22785A, waypoint_type JUMP_GATE, systems_in_range {X1-M73,X1-UD25,X1-VB95,X1-JF24,X1-ZF49,X1-YX61,X1-KB63,X1-VM9,X1-UM75,X1-PU62,X1-QM91,X1-YM2,X1-PG39}
# system: X1-YX61, system_waypoint: X1-YX61-54698Z, waypoint_type JUMP_GATE, systems_in_range {X1-JF24,X1-KB63,X1-ZF49,X1-M73,X1-VB95,X1-UH84,X1-UD25,X1-QM91,X1-UM75,X1-XH32}
# ...
